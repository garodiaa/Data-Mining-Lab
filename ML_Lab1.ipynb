# %% [markdown]
# # Data Mining Lab 1
# This notebook documents Lab 1 activities, including dataset understanding, initial preprocessing, and foundational analysis for the course.

# %% [markdown]
# # Data Mining Lab - 1
# ### **25 Aug 2024**

# %%
x = 2 if 5>6 else 11
print(x)
# Out:
# 11

# %%
x = int(input("Your Marks: "))
if x>100 or x<0:
  print("Marks input not valid")
elif x>=80:
  print("A+")
elif x>=75:
  print("A")
elif x>=70:
  print("A-")
elif x>=65:
  print("B")
elif x>=60:
  print("B+")
elif x>=55:
  print("C")
elif x>=50:
  print("D")
else:
  print("F")
# Out:
# Your Marks: -3
# Marks input not valid

# %%
age = 24
name = 'Sourav'
txt = '{} is {}'
print(txt.format(name,age))
# Out:
# Sourav is 24

# %%
arr = [1,2,3,4]
x = arr.pop()
print(x)
print(arr)
# Out:
# 4
# [1, 2, 3]
