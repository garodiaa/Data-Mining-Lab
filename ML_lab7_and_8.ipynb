# %% [markdown]
# # Data Mining Lab 7 and 8
# This notebook combines Lab 7 and Lab 8 exercises, documenting end-to-end analysis, model development, and conclusions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataMining_Lab/A Survey of Child Malnutrition Based on Machine Learning.csv')

# %%
df.head()
# Out:
#              Timestamp     What is your name?  What is your age?  \
# 0  12/24/2022 15:02:36  Ayesha Siraji Shejuty                 21
# 1  12/24/2022 15:08:21        Nushrah Ipshita                 18
# 2  12/24/2022 15:09:34      Nabhan Ezaz Ilhan                 18
# 3  12/24/2022 17:38:50   Rashedul Hoque Robin                 23
# 4  12/24/2022 17:50:51        Mubashira Hoque                 22
#
#   What is your gender? A child should sleep?  \
# 0               Female            8 to 9 hrs
# 1               Female            8 to 9 hrs
# 2                 Male            8 to 9 hrs
# 3                 Male            8 to 9 hrs
# 4               Female           9 to 10 hrs
#
#   At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                        3 to 6 year
# 1                                        3 to 6 year
# 2                                        3 to 6 year
# 3                                        3 to 6 year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 18 columns):
#  #   Column                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                              --------------  -----
#  0   Timestamp                                                                                                                                           411 non-null    object
#  1   What is your name?                                                                                                                                  411 non-null    object
#  2   What is your age?                                                                                                                                   411 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                             0
# What is your name?                                                                                                                                    0
# What is your age?                                                                                                                                     0
# What is your gender?                                                                                                                                  0
# A child should sleep?                                                                                                                                 0
# At what ages do food allergies, iron deficiency and occur in children?                                                                                0
# ...

# %%
df['What is your gender?'].value_counts()
# Out:
# What is your gender?
# Male      207
# Female    204
# Name: count, dtype: int64

# %%
df['What is your gender?'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='What is your gender?'>

# %% [markdown]
# ## Label encoding

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'What is your name?', 'What is your age?', 'What is your gender?', 'A child should sleep?', 'At what ages do food allergies, iron deficiency and occur in children?', 'During the early growing stage of a child the cause of malnutrition according to you is-', 'Child nutrition can also effect by', 'During puberty most of the child need to take proper amount of nutrients because', 'The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be', 'A girl child needs to have best care during puberty', 'The most common malnutrition of children in our country', 'Do you prefer parental awareness in case of a sound health of a child', 'Nutrition of a child related to', 'Diarrhea is a very common disease of infant. According to you it happens due to', 'Some people think that feeding a child more and more Can increase their body growth. But according to you it is a', 'Whole grain foods such as bread
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
one = le.fit_transform(df['What is your gender?'])

# %%
pd.DataFrame(one,columns=['gender'])
# Out:
#      gender
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0
# ..      ...
# 406       0
# 407       1
# 408       1
# 409       1
# 410       1
#
# [411 rows x 1 columns]

# %% [markdown]
# # **Lab 8 - 3 Nov 2024**

# %%
df.drop(['Timestamp', 'What is your name?'],axis=1,inplace=True)
# by default axis is zero which is row, but we will set it to column that is 1

# %%
df
# Out:
#      What is your age? What is your gender? A child should sleep?  \
# 0                   21               Female            8 to 9 hrs
# 1                   18               Female            8 to 9 hrs
# 2                   18                 Male            8 to 9 hrs
# 3                   23                 Male            8 to 9 hrs
# 4                   22               Female           9 to 10 hrs
# ..                 ...                  ...                   ...
# 406                 19               Female            8 to 9 hrs
# 407                 21                 Male            8 to 9 hrs
# 408                 23                 Male            8 to 9 hrs
# 409                 21                 Male            8 to 9 hrs
# 410                 29                 Male            8 to 9 hrs
#
#     At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                          3 to 6 year
# ...

# %% [markdown]
# ## **Manual Label encoding**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.columns.tolist()
# Out:
# ['What is your age?',
#  'What is your gender?',
#  'A child should sleep?',
#  'At what ages do food allergies, iron deficiency and occur in children?',
#  'During the early growing stage of a child the cause of malnutrition according to you is-',
#  'Child nutrition can also effect by',
#  'During puberty most of the child need to take proper amount of nutrients because',
#  'The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be',
#  'A girl child needs to have best care during puberty',
#  'The most common malnutrition of children in our country',
#  'Do you prefer parental awareness in case of a sound health of a child',
#  'Nutrition of a child related to',
#  'Diarrhea is a very common disease of infant. According to you it happens due to',
#  'Some people think that feeding a child more and more Can increase their body growth. But according to you it is a',
# ...

# %%
one = le.fit_transform(df['What is your gender?'])
two = le.fit_transform(df['A child should sleep?'])
three = le.fit_transform(df['At what ages do food allergies, iron deficiency and occur in children?'])
four = le.fit_transform(df['During the early growing stage of a child the cause of malnutrition according to you is-'])
five = le.fit_transform(df['During puberty most of the child need to take proper amount of nutrients because'])
six = le.fit_transform(df['The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be'])
seven = le.fit_transform(df['A girl child needs to have best care during puberty'])
eight = le.fit_transform(df['The most common malnutrition of children in our country'])
nine = le.fit_transform(df['Do you prefer parental awareness in case of a sound health of a child'])
ten = le.fit_transform(df['Nutrition of a child related to'])
eleven = le.fit_transform(df['Diarrhea is a very common disease of infant. According to you it happens due to'])
twelve = le.fit_transform(df['Some people think that feeding a child more and more Can increase their body growth. But according to you it is a'])
thirteen = le.fit_transform(df['Whole grain foods such as breads, cereals that are high in Fibre'])
fourteen = le.fit_transform(df['Toddlers & preschoolers should have following nutrients in their diet'])

# %%
df['What is your gender?']=one
df['A child should sleep?']=two
df['At what ages do food allergies, iron deficiency and occur in children?']=three
df['During the early growing stage of a child the cause of malnutrition according to you is-']=four
df['During puberty most of the child need to take proper amount of nutrients because']=five
df['The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be']=six
df['A girl child needs to have best care during puberty']=seven
df['The most common malnutrition of children in our country']=eight
df['Do you prefer parental awareness in case of a sound health of a child']=nine
df['Nutrition of a child related to']=ten
df['Diarrhea is a very common disease of infant. According to you it happens due to']=eleven
df['Some people think that feeding a child more and more Can increase their body growth. But according to you it is a']=twelve
df['Whole grain foods such as breads, cereals that are high in Fibre']=thirteen
df['Toddlers & preschoolers should have following nutrients in their diet']=fourteen

# %%
df
# Out:
#      What is your age?  What is your gender?  A child should sleep?  \
# 0                   21                     0                      1
# 1                   18                     0                      1
# 2                   18                     1                      1
# 3                   23                     1                      1
# 4                   22                     0                      2
# ..                 ...                   ...                    ...
# 406                 19                     0                      1
# 407                 21                     1                      1
# 408                 23                     1                      1
# 409                 21                     1                      1
# 410                 29                     1                      1
#
#      At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                                    1
# ...

# %% [markdown]
# ## **Feature Enginnering**

# %%
features=[
    'What is your gender?',
 'A child should sleep?',
 'At what ages do food allergies, iron deficiency and occur in children?',
 'During the early growing stage of a child the cause of malnutrition according to you is-',
 'During puberty most of the child need to take proper amount of nutrients because',
 'The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be',
 'A girl child needs to have best care during puberty',
 'The most common malnutrition of children in our country',
 'Do you prefer parental awareness in case of a sound health of a child',
 'Nutrition of a child related to',
 'Diarrhea is a very common disease of infant. According to you it happens due to',
 'Some people think that feeding a child more and more Can increase their body growth. But according to you it is a',
 'Whole grain foods such as breads, cereals that are high in Fibre',
 'Toddlers & preschoolers should have following nutrients in their diet'
]

# %%
x = df[features]

# %%
y = df['Child nutrition can also effect by']

# %%
from sklearn.feature_selection import SelectKBest #feature gula theke jegula beshi imp segula ber korte help kore
from sklearn.feature_selection import chi2 #helps in calculation of how impactfull the features are

# %%
sk = SelectKBest(score_func=chi2)

# %%
sk_f = sk.fit(x,y)

# %%
score = pd.DataFrame(sk_f.scores_ , columns = ['score'],)

# %%
s_col = pd.DataFrame(x.columns)

# %%
sk_df = pd.concat([s_col,score],axis=1)

sk_df
# Out:
#                                                     0      score
# 0                                What is your gender?   1.691957
# 1                               A child should sleep?   3.883915
# 2   At what ages do food allergies, iron deficienc...   0.863199
# 3   During the early growing stage of a child the ...   4.458112
# 4   During puberty most of the child need to take ...  15.883135
# 5   The most important nutrition source of  an inf...  10.722651
# 6   A girl child needs to have best care during pu...  15.263343
# 7   The most common malnutrition of children in ou...   4.355552
# 8   Do you prefer parental awareness in case of a ...   3.464210
# 9                     Nutrition of a child related to   8.700278
# 10  Diarrhea is a very common disease of infant. A...   5.279076
# 11  Some people think that feeding a child more an...   3.144727
# 12  Whole grain foods such as breads, cereals that...   6.299795
# ...

# %%
sk_df.sort_values(by='score',ascending=False)
# Out:
#                                                     0      score
# 4   During puberty most of the child need to take ...  15.883135
# 6   A girl child needs to have best care during pu...  15.263343
# 5   The most important nutrition source of  an inf...  10.722651
# 9                     Nutrition of a child related to   8.700278
# 13  Toddlers & preschoolers should have following ...   7.437588
# 12  Whole grain foods such as breads, cereals that...   6.299795
# 10  Diarrhea is a very common disease of infant. A...   5.279076
# 3   During the early growing stage of a child the ...   4.458112
# 7   The most common malnutrition of children in ou...   4.355552
# 1                               A child should sleep?   3.883915
# 8   Do you prefer parental awareness in case of a ...   3.464210
# 11  Some people think that feeding a child more an...   3.144727
# 0                                What is your gender?   1.691957
# ...

# %%
 df['Child nutrition can also effect by'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Child nutrition can also effect by'>

# %% [markdown]
# # **Lab 9 - 10 Nov**

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dtc.predict(xtest)
# Out:
# array(['Environment', 'Environment', 'Quantity of intake food',
#        'Family care', 'Environment', 'Environment', 'Family care',
#        'Physical well-being', 'Environment', 'Environment', 'Environment',
#        'Physical well-being', 'Environment', 'Environment', 'Environment',
#        'Family care', 'Environment', 'Environment',
#        'Quantity of intake food', 'Physical well-being', 'Family care',
#        'Environment', 'Family care', 'Environment', 'Environment',
#        'Environment', 'Environment', 'Environment', 'Physical well-being',
#        'Family care', 'Family care', 'Family care', 'Environment',
#        'Physical well-being', 'Family care', 'Family care', 'Environment',
#        'Family care', 'Environment', 'Environment', 'Physical well-being',
#        'Environment', 'Family care', 'Physical well-being', 'Environment',
#        'Physical well-being', 'Environment', 'Physical well-being',
#        'Environment', 'Physical well-being', 'Environment',
# ...

# %%
y_pred = dtc.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,y_pred)
# Out:
# 0.37349397590361444

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(ytest,y_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.54      0.59      0.56        37
#             Family care       0.30      0.18      0.23        33
#     Physical well-being       0.20      0.33      0.25         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.37        83
#               macro avg       0.26      0.28      0.26        83
#            weighted avg       0.38      0.37      0.37        83

# %%
print(confusion_matrix(ytest,y_pred))
# Out:
# [[22 10  4  1]
#  [18  6  6  3]
#  [ 1  2  3  3]
#  [ 0  2  2  0]]

# %%
sns.heatmap(confusion_matrix(ytest,y_pred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred = rfc.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.4939759036144578

# %%
print(classification_report(ytest,ypred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.53      0.70      0.60        37
#             Family care       0.60      0.45      0.52        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.49        83
#               macro avg       0.28      0.29      0.28        83
#            weighted avg       0.48      0.49      0.48        83

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
svcy_pred = svc.predict(xtest)

# %%
print(classification_report(ytest,svcy_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.48      0.81      0.61        37
#             Family care       0.50      0.27      0.35        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.47        83
#               macro avg       0.25      0.27      0.24        83
#            weighted avg       0.41      0.47      0.41        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
sns.heatmap(confusion_matrix(ytest,svcy_pred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc = KNeighborsClassifier()
knc.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
kncy_pred = knc.predict(xtest)

# %%
print(classification_report(ytest,kncy_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.43      0.62      0.51        37
#             Family care       0.42      0.33      0.37        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.41        83
#               macro avg       0.21      0.24      0.22        83
#            weighted avg       0.36      0.41      0.37        83
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
sns.heatmap(confusion_matrix(ytest,kncy_pred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
gnby_pred = gnb.predict(xtest)

# %%
print(classification_report(ytest,gnby_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.53      0.73      0.61        37
#             Family care       0.63      0.36      0.46        33
#     Physical well-being       0.09      0.11      0.10         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.48        83
#               macro avg       0.31      0.30      0.29        83
#            weighted avg       0.50      0.48      0.47        83

# %%
sns.heatmap(confusion_matrix(ytest,gnby_pred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(xtrain,ytrain)
# Out:
# GradientBoostingClassifier()

# %%
gbcy_pred = gbc.predict(xtest)

# %%
print(classification_report(ytest,gbcy_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.61      0.73      0.67        37
#             Family care       0.48      0.30      0.37        33
#     Physical well-being       0.17      0.22      0.19         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.47        83
#               macro avg       0.31      0.31      0.31        83
#            weighted avg       0.48      0.47      0.47        83

# %%
sns.heatmap(confusion_matrix(ytest,gbcy_pred),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
lry_pred = lr.predict(xtest)

# %%
print(classification_report(ytest,lry_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.55      0.78      0.64        37
#             Family care       0.64      0.42      0.51        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.52        83
#               macro avg       0.30      0.30      0.29        83
#            weighted avg       0.50      0.52      0.49        83

# %%
sns.heatmap(confusion_matrix(ytest,lry_pred),annot=True)
# Out:
# <Axes: >

# %%
# !pip install catboost
from catboost import CatBoostClassifier
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.0 MB/s eta 0:00:00
# ...

# %%
cbc = CatBoostClassifier()
cbc.fit(xtrain, ytrain)
# Out:
# Learning rate set to 0.074754
# 0:	learn: 1.3557698	total: 48.3ms	remaining: 48.2s
# 1:	learn: 1.3315602	total: 50.6ms	remaining: 25.3s
# 2:	learn: 1.3042652	total: 53ms	remaining: 17.6s
# 3:	learn: 1.2819302	total: 58.8ms	remaining: 14.6s
# 4:	learn: 1.2595616	total: 61.5ms	remaining: 12.2s
# 5:	learn: 1.2409807	total: 65.3ms	remaining: 10.8s
# 6:	learn: 1.2252144	total: 66.7ms	remaining: 9.46s
# 7:	learn: 1.2090200	total: 68.1ms	remaining: 8.44s
# 8:	learn: 1.1908564	total: 75.1ms	remaining: 8.27s
# 9:	learn: 1.1760463	total: 76.6ms	remaining: 7.58s
# 10:	learn: 1.1639790	total: 77.5ms	remaining: 6.97s
# 11:	learn: 1.1497172	total: 80.6ms	remaining: 6.63s
# 12:	learn: 1.1341728	total: 83.7ms	remaining: 6.35s
# 13:	learn: 1.1213859	total: 88.1ms	remaining: 6.2s
# 14:	learn: 1.1096058	total: 90.6ms	remaining: 5.95s
# 15:	learn: 1.0964013	total: 97ms	remaining: 5.97s
# 16:	learn: 1.0822609	total: 98.5ms	remaining: 5.7s
# 17:	learn: 1.0696907	total: 99.8ms	remaining: 5.45s
# ...

# %%
cbcy_pred = cbc.predict(xtest)

# %%
print(classification_report(ytest,cbcy_pred))
# Out:
#                          precision    recall  f1-score   support
#
#             Environment       0.54      0.68      0.60        37
#             Family care       0.58      0.45      0.51        33
#     Physical well-being       0.11      0.11      0.11         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.49        83
#               macro avg       0.31      0.31      0.31        83
#            weighted avg       0.48      0.49      0.48        83

# %%
sns.heatmap(confusion_matrix(ytest,cbcy_pred),annot=True)
# Out:
# <Axes: >
