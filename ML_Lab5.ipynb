# %% [markdown]
# # Data Mining Lab 5
# This notebook contains Lab 5 implementation details with analysis, model execution, and interpretation of results for course documentation.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/cse.csv",usecols = ['Age'])

# %%
df.head()
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
df['Age'].sample()
# Out:
# 774    54.0
# Name: Age, dtype: float64

# %%
df['Age'].dropna().sample(df['Age'].isnull().sum(),random_state=0) #random_state = 0 means bar bar value change hbena
# Out:
# 423    28.00
# 177    50.00
# 305     0.92
# 292    36.00
# 889    26.00
#        ...
# 539    22.00
# 267    25.00
# 352    15.00
# 99     34.00
# 689    15.00
# Name: Age, Length: 177, dtype: float64

# %%
def input_random(df,variable):
  df[variable+'_random']=df[variable]
  random_sample = df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
  random_sample.index = df[df[variable].isnull()].index
  df.loc[df[variable].isnull(),variable+'_random'] = random_sample
  return df

# %%
df_1 = input_random(df,'Age')
df_1
# Out:
#       Age  Age_random
# 0    22.0        22.0
# 1    38.0        38.0
# 2    26.0        26.0
# 3    35.0        35.0
# 4    35.0        35.0
# ..    ...         ...
# 886  27.0        27.0
# 887  19.0        19.0
# 888   NaN        15.0
# 889  26.0        26.0
# 890  32.0        32.0
#
# [891 rows x 2 columns]

# %%
df['Age'].plot(kind='kde',color='red')
df['Age_random'].plot(kind='kde',color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd = StandardScaler() # this is z-score

# %%
sd.fit_transform(df_1)
# Out:
# array([[-0.53037664, -0.52903431],
#        [ 0.57183099,  0.5702081 ],
#        [-0.25482473, -0.25422371],
#        ...,
#        [        nan, -1.00995287],
#        [-0.25482473, -0.25422371],
#        [ 0.15850313,  0.15799219]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
norm = MinMaxScaler() #for normalization

# %%
norm.fit_transform(df_1)
# Out:
# array([[0.27117366, 0.27117366],
#        [0.4722292 , 0.4722292 ],
#        [0.32143755, 0.32143755],
#        ...,
#        [       nan, 0.18321186],
#        [0.32143755, 0.32143755],
#        [0.39683338, 0.39683338]])
